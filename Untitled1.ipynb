# %% [markdown]
# <a href="https://colab.research.google.com/github/shun0109/colab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "smiyamot@bu.edu"
# !git config --global user.name "shun0109"
# !git config --global credential.helper cache
import os
token = userdata.get('GITHUB_TOKEN')
# !git clone https://x-access-token:{token}@github.com/shun0109/colab.git
# %cd colab
# Out:
# Cloning into 'colab'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 28 (delta 10), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 458.94 KiB | 5.53 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/colab

# %%
# !git pull
# Out:
# Already up to date.

# %%
import requests
import pandas as pd
import urllib
# !pip install mecab-python3 ipadic neologdn
import MeCab, ipadic
import neologdn
import re
# !pip install spacy
! pip install ginza > /dev/null 2>&1
! python -m spacy download ja_core_news_sm > /dev/null 2>&1

# import pkg_resources, imp
# imp.reload(pkg_resources)
import spacy
from spacy import displacy
# !pip install kaggle --upgrade
from google.colab import files
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 47.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.8/588.8 kB 31.2 MB/s eta 0:00:00
# ...
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=49bc49b50da3b4d479b34df32ace242cf362afc54f00251da21bf580ab886ad5
#   Stored in directory: /root/.cache/pip/wheels/44/56/37/f543963822b85260c9f948df8fac8c20169c80dc71b24dc407
# ...
#   Created wheel for neologdn: filename=neologdn-0.5.4-cp311-cp311-linux_x86_64.whl size=231433 sha256=d9c3c429f948b3944f0a6f024649ef1c15ce587da6ecab6a7ca6fb760ca0604e
#   Stored in directory: /root/.cache/pip/wheels/4b/0e/04/6fe075d8dbc3c114a0bcbab6f5c4201283d66ba59e89bbad8a
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-f43ecc6f-ceda-409b-8c49-49fe9bf8929a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f43ecc6f-ceda-409b-8c49-49fe9bf8929a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# url='https://raw.githubusercontent.com/shun0109/colab/refs/heads/main/tdnet_20250408_with_text.csv'
# df=pd.read_csv(url)

# %%
df.head()
# Out:
#     Time   Code                 Company                                Title  \
# 0  19:30  54010  日本製鉄                    （開示事項の変更）当社子会社による自己株式の消却の中止に関するお知らせ
# 1  19:30  54490  大阪製鉄                                     自己株式の消却の中止に関するお知らせ
# 2  19:10  13990          上場高配当低ボラ                              ＥＴＦの収益分配のお知らせ
# 3  19:10  14900          上場ベータヘッジ                              ＥＴＦの収益分配のお知らせ
# 4  19:10  16980  上場配当                                          ＥＴＦの収益分配のお知らせ
#
#                  PDF_Link XBRL_Link  \
# 0  140120250408510675.pdf       NaN
# 1  140120250408510529.pdf       NaN
# 2  140120250408511088.pdf       NaN
# 3  140120250408511089.pdf       NaN
# 4  140120250408511090.pdf       NaN
#
#                                             PDF_Text
# 0  2025年４月８日\n各 位\n会社名 日本製鉄株式会社\n代表者名 代表取締役社長 兼 Ｃ...
# 1  2025年４月８日\n各 位\n会 社 名 大 阪 製 鐵株 式 会 社\n代表者名 代表取...
# 2  2025年4月8日\n各 位\n委託会社名 日興アセットマネジメント株式会社\n代表者名 代...
# 3  2025年4月8日\n各 位\n委託会社名 日興アセットマネジメント株式会社\n代表者名 代...
# ...

# %%
# !kaggle datasets download lazon282/japanese-stop-words

# %%
# !unzip japanese-stop-words -d japanese-stop-words

# %%
with open('./japanese-stop-words/Japanese_stopword_list.txt') as f:
      stop_words = f.read().splitlines()

# %%
mecab=MeCab.Tagger(ipadic.MECAB_ARGS)

# %%
def normalization(text):
  text = text.replace('\n','').replace('\r','')
  text = re.sub(r'http?://[\w/:%#\$&\?\(\)~\.=\+\-]+', '', text)
  text = re.sub(r'https?://[\w/:%#\$&\?\(\)~\.=\+\-]+','', text)
  text = re.sub(r'\d+', '0', text)
  text = text.lower()
  return neologdn.normalize(text)

def get_base_forms(text):
    # mecab = MeCab.Tagger()
    nodes = mecab.parseToNode(text)
    base_forms = []
    while nodes:
        if nodes.surface != "":
            features = nodes.feature.split(',')
            pos=features[0]
            lemma=features[6] if len(features) > 7 else nodes.surface
            if pos not in ['助詞','助動詞','記号'] and lemma not in stop_words and lemma !='BOS/EOS':
              base_forms.append(lemma)
        nodes = nodes.next
    return base_forms

# # 使用例
# text = "私は日本語を勉強しています。"
# text=normalization(text)
# base_forms = get_base_forms(text)
# print(base_forms)

# %%
txt=df['PDF_Text'][0]
txt=normalization(txt)
print(get_base_forms(txt))

# %%
nlp = spacy.load('ja_core_news_sm')
def split_sentences(text):
    doc = nlp(text)
    return [sent.text.strip() for sent in doc.sents]

# %%
def preprocess(df,col_name):
  normalized_txt=[]
  splitted_sentences=[]
  token_lists=[]

  for text in df[col_name]:
    try:
      norm=normalization(text)
      sents=split_sentences(norm)
      tokenized_sents=[get_base_forms(s) for s in sents]

      normalized_txt.append(norm)
      splitted_sentences.append(sents)
      token_lists.append(tokenized_sents)
    except Exception as e:
      print(f"[ERROR] {e}")
      normalized_txt.append('')
      splitted_sentences.append([])
      token_lists.append([])

  df['Normalized_Text']=normalized_txt
  df['Sentences']=splitted_sentences
  df['Tokenized_Sentence']=token_lists
  return df

# %%
# df_txt=preprocess(df,'PDF_Text')

# %%
# df_txt['Tokenized_Sentence'][5]

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
import shutil
shutil.copy('/content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb', '/content/colab/Preprocessing.ipynb')
# Out:
# '/content/colab/Preprocessing.ipynb'

# %%
# !git add Preprocessing.ipynb

# %%
# !git add .
import subprocess

remote_url = f"https://x-access-token:{token}@github.com/shun0109/colab.git"
subprocess.run(["git", "remote", "set-url", "origin", remote_url])
subprocess.run(["git", "push", "origin", "main"])
# Out:
# CompletedProcess(args=['git', 'push', 'origin', 'main'], returncode=1)
